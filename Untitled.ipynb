# %% [markdown]
# # Kunal Dipak Deore
# MSc-2
# roll no:- 14
# PRN NO: MA19100303
# SUBJECT - PROGRAMMING IN PYTHON(MTUT 143)
# L. V. H. Arts, Science and Commerce College, Panchavati, Nashik – 003

# %% [markdown]
# # Practical 1

# %% [markdown]
# A] Explain a few applications of Python.
#
# ==> python can be used as scripting as well as object oriented programming language
# 1.web development
# 2.GUI development
# 3.softwere development
# 4.scientific applications,ex:scipy

# %% [markdown]
# B] Explain the chronology of the development of Python.
#
# ==> The programming language Python was conceived in the late 1980s, and its
# implementation was started in December 1989 by Guido van Rossum at CWI in the
# Netherlands as a successor to ABC capable of exception handling and interfacing
# with the Amoeba operating system.story : guido van rossum developer of pyhton
# loves to watch BBc show named flying circus and he really like the performance
# of Monty python in show so therfore he named this programming language after
# monty python name.

# %% [markdown]
# C] Name some Editors in Python.
#
# ==> Multiplatform Editors
#     Name	Platform	Impl. Language
#     PyCharm	Linux, Windows, Mac OS X	Java
#     PyDev	Linux, Windows, Mac OS X	Java, Eclipse
#     Pye	Linux, Windows	Python, Tk
#     PyPE
# pycharm , jupyter notebook ,spyder,GitHub, atom and sublime etc..

# %% [markdown]
# D] What languages can be supported by Python?
#
# ==> python is multi paradigim language it supports object oriented programming
# ,structured programming language also used as functional programming
# languagepyhton can be integrated programming language such as c ,c++ , java and
# sql.

# %% [markdown]
# E] What is the advantage of using Python over other languages?
#
# ==>python is beginner friendly language has less syntax compared to other
# programming language , it has many useful inbuilt feature and as it is part of
# open source ,their is wide community of python which contributes to making
# amazing libraries for pyhthon . its supports oops programming, many libraries
# are availabel for AI and Ml .

# %% [markdown]
# F] Name data types in Python. (If any).
#
# ==> 1) independent data types = string , integer , float , complex number and
# boolean
#     2) dependent data types = tupal , list , dictionary and set.

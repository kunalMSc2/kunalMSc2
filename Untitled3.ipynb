# %% [markdown]
# # Kunal Dipak Deore
# MSc-2
# roll no:- 14
# PRN NO: MA19100303
# SUBJECT - PROGRAMMING IN PYTHON(MTUT 143)
# L. V. H. Arts, Science and Commerce College, Panchavati, Nashik – 003

# %% [markdown]
# # Practical 3

# %% [markdown]
# A] Write a python programme which accept an integer between 1000 and 9999 and find sum of its digits.

# %%
num=int(input("Enter a four digit number\t:"))
if((num<9999) | (num>1000)):
	print("you have not entered a number between 1000 and 9999")
else:
	flag=0
num = int(input("Input a four digit numbers: "))
x  = num //1000
x1 = (num - x*1000)//100
x2 = (num - x*1000 - x1*100)//10
x3 = num - x*1000 - x1*100 - x2*10
print("The sum of digits in the number is", x+x1+x2+x3)
# Out:
# Enter a four digit number	:9999
# you have not entered a number between 1000 and 9999
# Input a four digit numbers: 1234
# The sum of digits in the number is 10

# %% [markdown]
# B] Write a python programme which accept 3 digit number and display its reverse.

# %%
a = int(input("enter any three digit number : "))
if a>99 and a<1000 :
    third = a%10          
    second = int(a/10)%10  
    first = int(a/100)%10  
    add = str(third) + str(second) + str(first) 
    print("our reversed number :",int(add)) 
else :
    print("enter valid number")
# Out:
# enter any three digit number : 789
# our reversed number : 987

# %% [markdown]
# C] Write a python programme which accept 4 digit number and display the number which is at 10th unit place.

# %%
n = int(input("enter 4 digit integer "))   
if n> 999 and n <10000:        
    output = int(n/10)%10         
    print("number at 10 the position is {0} ".format(output))
else :                              
    print("enter correct number")
# Out:
# enter 4 digit integer 4567
# number at 10 the position is 6

# %% [markdown]
# D] Write a python programme which accept an integer and display whether it is even or odd.

# %%
num = int(input("Enter a number: "))
if (num % 2) == 0:
   print("{0} is Even".format(num))
else:
   print("{0} is Odd".format(num))
# Out:
# Enter a number: 75
# 75 is Odd

# %%
num = int(input("Enter a number: "))
if (num % 2) == 0:
   print("{0} is Even".format(num))
else:
   print("{0} is Odd".format(num))
# Out:
# Enter a number: 22
# 22 is Even

# %% [markdown]
# E] Write a python programme which accept a year and display whether it is leap year or not.

# %%
year=int(input("Enter year to be checked:"))
if(year%4==0 and year%100!=0 or year%400==0):
    print("The year is a leap year!")
else:
    print("The year isn't a leap year!")
# Out:
# Enter year to be checked:2021
# The year isn't a leap year!

# %%
year=int(input("Enter year to be checked:"))
if(year%4==0 and year%100!=0 or year%400==0):
    print("The year is a leap year!")
else:
    print("The year isn't a leap year!")
# Out:
# Enter year to be checked:2016
# The year is a leap year!

# %% [markdown]
# F] Write a python programme which accept 3 distinct integers and display the greatest among them.

# %%
# take three numbers from user
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))
 
if (num1 > num2) and (num1 > num3):
   largest = num1
elif (num2 > num1) and (num2 > num3):
   largest = num2
else:
   largest = num3
 
print("The largest number is",largest)
# Out:
# Enter first number: 22
# Enter second number: 88
# Enter third number: 66
# The largest number is 88.0

# %% [markdown]
# G] Write a python programme which accept a number and display whether it is divisible by 3 and 13.

# %%
number = int(input(" Please Enter any Positive Integer : "))

if((number % 3 == 0) and (number % 13 == 0)):
    print("Given Number {0} is Divisible by 3 and 13".format(number))
else:
    print("Given Number {0} is Not Divisible by 3 and 13".format(number))
# Out:
#  Please Enter any Positive Integer : 27
# Given Number 27 is Not Divisible by 3 and 13

# %%
number = int(input(" Please Enter any Positive Integer : "))

if((number % 3 == 0) and (number % 13 == 0)):
    print("Given Number {0} is Divisible by 3 and 13".format(number))
else:
    print("Given Number {0} is Not Divisible by 3 and 13".format(number))
# Out:
#  Please Enter any Positive Integer : 39
# Given Number 39 is Divisible by 3 and 13
